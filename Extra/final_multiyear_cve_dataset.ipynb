# %%
import pandas as pd
import numpy as np

data_2020 = pd.read_csv('data/cve_2020.csv')
data_2019 = pd.read_csv('data/cve_2019.csv')
data_2018 = pd.read_csv('data/cve_2018.csv')
#data_2017 = pd.read_csv('data/cve_2017.csv')

print(data_2020.shape)
print(data_2019.shape)
#print(data_2018.shape)
#print(data_2017.shape)
# Out:
# (15624, 21)
# (16258, 21)

# %%
#data = pd.concat([data_2020, data_2019, data_2018, data_2017])
data = pd.concat([data_2020, data_2019, data_2018])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48427 entries, 0 to 16544
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   publishedDate                 48427 non-null  object
#  1   lastModifiedDate              48427 non-null  object
#  2   CVE_ID                        48427 non-null  object
#  3   description                   48427 non-null  object
#  4   cvssV3_version                45926 non-null  float64
#  5   cvssV3_vectorString           45926 non-null  object
#  6   cvssV3_attackVector           45926 non-null  object
#  7   cvssV3_attackComplexity       45926 non-null  object
#  8   cvssV3_privilegesRequired     45926 non-null  object
#  9   cvssV3_userInteraction        45926 non-null  object
#  10  cvssV3_scope                  45926 non-null  object
#  11  cvssV3_confidentialityImpact  45926 non-null  object
#  12  cvssV3_integrityImpact        45926 non-null  object
#  13  cvssV3_availabilityImpact     45926 non-null  object
#  14  cvssV3_baseScore              45926 non-null  float64
#  15  cvssV3_baseSeverity           45926 non-null  object
#  16  V3_exploitabilityScore        45926 non-null  float64
#  17  V3_impactScore                45926 non-null  float64
#  18  nb_CWE                        48427 non-null  int64
#  19  CWE1                          48427 non-null  object
#  20  CWE2                          48427 non-null  object
# dtypes: float64(4), int64(1), object(16)
# memory usage: 8.1+ MB

# %%
data[["Description", "Product"]] = data["description"].str.split("Product:", expand=True)
data.drop(columns=['description'], inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48427 entries, 0 to 16544
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   publishedDate                 48427 non-null  object
#  1   lastModifiedDate              48427 non-null  object
#  2   CVE_ID                        48427 non-null  object
#  3   cvssV3_version                45926 non-null  float64
#  4   cvssV3_vectorString           45926 non-null  object
#  5   cvssV3_attackVector           45926 non-null  object
#  6   cvssV3_attackComplexity       45926 non-null  object
#  7   cvssV3_privilegesRequired     45926 non-null  object
#  8   cvssV3_userInteraction        45926 non-null  object
#  9   cvssV3_scope                  45926 non-null  object
#  10  cvssV3_confidentialityImpact  45926 non-null  object
#  11  cvssV3_integrityImpact        45926 non-null  object
#  12  cvssV3_availabilityImpact     45926 non-null  object
#  13  cvssV3_baseScore              45926 non-null  float64
#  14  cvssV3_baseSeverity           45926 non-null  object
#  15  V3_exploitabilityScore        45926 non-null  float64
#  16  V3_impactScore                45926 non-null  float64
#  17  nb_CWE                        48427 non-null  int64
#  18  CWE1                          48427 non-null  object
#  19  CWE2                          48427 non-null  object
#  20  Description                   48427 non-null  object
#  21  Product                       1075 non-null   object
# dtypes: float64(4), int64(1), object(17)
# memory usage: 8.5+ MB

# %%
data.loc[data['cvssV3_baseSeverity'].isnull()]
# Out:
#            publishedDate   lastModifiedDate          CVE_ID  cvssV3_version  \
# 229    2021-01-28T02:15Z  2021-01-28T02:15Z   CVE-2020-0237             NaN
# 247    2020-08-14T20:15Z  2020-08-14T20:15Z   CVE-2020-0255             NaN
# 425    2020-09-17T19:15Z  2020-09-24T15:15Z   CVE-2020-0435             NaN
# 473    2020-12-15T16:15Z  2021-01-26T18:15Z   CVE-2020-0487             NaN
# 981    2020-03-07T00:15Z  2020-03-07T00:15Z  CVE-2020-10020             NaN
# ...                  ...                ...             ...             ...
# 16292  2018-04-06T16:29Z  2018-04-06T16:29Z   CVE-2018-9321             NaN
# 16294  2018-04-06T16:29Z  2018-04-06T16:29Z   CVE-2018-9323             NaN
# 16295  2018-04-06T16:29Z  2018-04-06T16:29Z   CVE-2018-9324             NaN
# 16300  2018-04-06T03:29Z  2018-04-13T01:29Z   CVE-2018-9329             NaN
# 16539  2018-06-04T06:29Z  2018-06-04T06:29Z   CVE-2018-9994             NaN
#
#       cvssV3_vectorString cvssV3_attackVector cvssV3_attackComplexity  \
# 229                   NaN                 NaN                     NaN
# 247                   NaN                 NaN                     NaN
# 425                   NaN                 NaN                     NaN
# 473                   NaN                 NaN                     NaN
# 981                   NaN                 NaN                     NaN
# ...                   ...                 ...                     ...
# 16292                 NaN                 NaN                     NaN
# 16294                 NaN                 NaN                     NaN
# 16295                 NaN                 NaN                     NaN
# 16300                 NaN                 NaN                     NaN
# 16539                 NaN                 NaN                     NaN
#
#       cvssV3_privilegesRequired cvssV3_userInteraction cvssV3_scope  ...  \
# 229                         NaN                    NaN          NaN  ...
# 247                         NaN                    NaN          NaN  ...
# 425                         NaN                    NaN          NaN  ...
# 473                         NaN                    NaN          NaN  ...
# 981                         NaN                    NaN          NaN  ...
# ...                         ...                    ...          ...  ...
# 16292                       NaN                    NaN          NaN  ...
# 16294                       NaN                    NaN          NaN  ...
# 16295                       NaN                    NaN          NaN  ...
# 16300                       NaN                    NaN          NaN  ...
# 16539                       NaN                    NaN          NaN  ...
#
#       cvssV3_availabilityImpact cvssV3_baseScore cvssV3_baseSeverity  \
# 229                         NaN              NaN                 NaN
# 247                         NaN              NaN                 NaN
# 425                         NaN              NaN                 NaN
# 473                         NaN              NaN                 NaN
# 981                         NaN              NaN                 NaN
# ...                         ...              ...                 ...
# 16292                       NaN              NaN                 NaN
# 16294                       NaN              NaN                 NaN
# 16295                       NaN              NaN                 NaN
# 16300                       NaN              NaN                 NaN
# 16539                       NaN              NaN                 NaN
#
#        V3_exploitabilityScore V3_impactScore  nb_CWE  CWE1  CWE2  \
# 229                       NaN            NaN       0  None  None
# 247                       NaN            NaN       0  None  None
# 425                       NaN            NaN       0  None  None
# 473                       NaN            NaN       0  None  None
# 981                       NaN            NaN       0  None  None
# ...                       ...            ...     ...   ...   ...
# 16292                     NaN            NaN       0  None  None
# 16294                     NaN            NaN       0  None  None
# 16295                     NaN            NaN       0  None  None
# 16300                     NaN            NaN       0  None  None
# 16539                     NaN            NaN       0  None  None
#
#                                              Description Product
# 229    ** REJECT ** DO NOT USE THIS CANDIDATE NUMBER....    None
# 247    ** REJECT ** DO NOT USE THIS CANDIDATE NUMBER....    None
# 425    ** REJECT ** DO NOT USE THIS CANDIDATE NUMBER....    None
# 473    ** REJECT ** DO NOT USE THIS CANDIDATE NUMBER....    None
# 981    ** REJECT ** Number assigned to issue that doe...    None
# ...                                                  ...     ...
# 16292  ** REJECT **  DO NOT USE THIS CANDIDATE NUMBER...    None
# 16294  ** REJECT **  DO NOT USE THIS CANDIDATE NUMBER...    None
# 16295  ** REJECT **  DO NOT USE THIS CANDIDATE NUMBER...    None
# 16300  ** REJECT **  DO NOT USE THIS CANDIDATE NUMBER...    None
# 16539  ** REJECT **  DO NOT USE THIS CANDIDATE NUMBER...    None
#
# [2501 rows x 22 columns]

# %%
data['cvssV3_baseSeverity'].value_counts(dropna=False)
# Out:
# HIGH        19939
# MEDIUM      18459
# CRITICAL     6735
# NaN          2501
# LOW           793
# Name: cvssV3_baseSeverity, dtype: int64

# %%
for col_name in list(data.columns.values[5:13]):
    print(col_name)
    print( data[col_name].value_counts(dropna=False) )
# Out:
# cvssV3_attackVector
# NETWORK             34090
# LOCAL               10093
# NaN                  2501
# ADJACENT_NETWORK     1150
# PHYSICAL              593
# Name: cvssV3_attackVector, dtype: int64
# cvssV3_attackComplexity
# LOW     42907
# HIGH     3019
# NaN      2501
# Name: cvssV3_attackComplexity, dtype: int64
# cvssV3_privilegesRequired
# NONE    29424
# LOW     12980
# HIGH     3522
# NaN      2501
# Name: cvssV3_privilegesRequired, dtype: int64
# cvssV3_userInteraction
# NONE        30039
# REQUIRED    15887
# NaN          2501
# Name: cvssV3_userInteraction, dtype: int64
# cvssV3_scope
# UNCHANGED    38055
# CHANGED       7871
# NaN           2501
# Name: cvssV3_scope, dtype: int64
# cvssV3_confidentialityImpact
# HIGH    27063
# NONE     9828
# LOW      9035
# NaN      2501
# Name: cvssV3_confidentialityImpact, dtype: int64
# cvssV3_integrityImpact
# HIGH    23517
# NONE    14171
# LOW      8238
# NaN      2501
# Name: cvssV3_integrityImpact, dtype: int64
# cvssV3_availabilityImpact
# HIGH    26141
# NONE    18641
# NaN      2501
# LOW      1144
# Name: cvssV3_availabilityImpact, dtype: int64

# %%
data = data[data['cvssV3_baseSeverity'].notna()]
data.shape
# Out:
# (45926, 22)

# %%
for col_name in list(data.columns.values[5:13]):
    print(col_name)
    print( data[col_name].value_counts(dropna=False)/data.shape[0])
# Out:
# cvssV3_attackVector
# NETWORK             0.742281
# LOCAL               0.219767
# ADJACENT_NETWORK    0.025040
# PHYSICAL            0.012912
# Name: cvssV3_attackVector, dtype: float64
# cvssV3_attackComplexity
# LOW     0.934264
# HIGH    0.065736
# Name: cvssV3_attackComplexity, dtype: float64
# cvssV3_privilegesRequired
# NONE    0.640683
# LOW     0.282629
# HIGH    0.076689
# Name: cvssV3_privilegesRequired, dtype: float64
# cvssV3_userInteraction
# NONE        0.654074
# REQUIRED    0.345926
# Name: cvssV3_userInteraction, dtype: float64
# cvssV3_scope
# UNCHANGED    0.828616
# CHANGED      0.171384
# Name: cvssV3_scope, dtype: float64
# cvssV3_confidentialityImpact
# HIGH    0.589274
# NONE    0.213996
# LOW     0.196730
# Name: cvssV3_confidentialityImpact, dtype: float64
# cvssV3_integrityImpact
# HIGH    0.512063
# NONE    0.308562
# LOW     0.179376
# Name: cvssV3_integrityImpact, dtype: float64
# cvssV3_availabilityImpact
# HIGH    0.569198
# NONE    0.405892
# LOW     0.024910
# Name: cvssV3_availabilityImpact, dtype: float64

# %%
data['cvssV3_baseSeverity'].value_counts(dropna=False)
# Out:
# HIGH        19939
# MEDIUM      18459
# CRITICAL     6735
# LOW           793
# Name: cvssV3_baseSeverity, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45926 entries, 0 to 16544
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   publishedDate                 45926 non-null  object
#  1   lastModifiedDate              45926 non-null  object
#  2   CVE_ID                        45926 non-null  object
#  3   cvssV3_version                45926 non-null  float64
#  4   cvssV3_vectorString           45926 non-null  object
#  5   cvssV3_attackVector           45926 non-null  object
#  6   cvssV3_attackComplexity       45926 non-null  object
#  7   cvssV3_privilegesRequired     45926 non-null  object
#  8   cvssV3_userInteraction        45926 non-null  object
#  9   cvssV3_scope                  45926 non-null  object
#  10  cvssV3_confidentialityImpact  45926 non-null  object
#  11  cvssV3_integrityImpact        45926 non-null  object
#  12  cvssV3_availabilityImpact     45926 non-null  object
#  13  cvssV3_baseScore              45926 non-null  float64
#  14  cvssV3_baseSeverity           45926 non-null  object
#  15  V3_exploitabilityScore        45926 non-null  float64
#  16  V3_impactScore                45926 non-null  float64
#  17  nb_CWE                        45926 non-null  int64
#  18  CWE1                          45926 non-null  object
#  19  CWE2                          45926 non-null  object
#  20  Description                   45926 non-null  object
#  21  Product                       1075 non-null   object
# dtypes: float64(4), int64(1), object(17)
# memory usage: 8.1+ MB

# %%
data.to_csv('./data/cve_2018-2020_complete_dataset.csv', index=False)
